# %% [markdown]
# # Qué hay acá?
#
# Simplemente paso 1_intermediate-sentimientos a la carpeta 2_processed, limpio un poco y genero un html con los resultados finales.
#
# Las tablas que estarán en el html generado serán las siguientes:
#
# - 0_texto(sinrep)_puntos3d.xlsx
# - 1_sentimientos.xlsx

# %%
import pandas as pd
# Out:
# c:\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# c:\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
sentimientos = pd.read_json('../data/1_intermediate/0_intermediate-sentimientos.json', orient='records', lines=True)
print(sentimientos.shape)
sentimientos.head()
# Out:
# (100, 5)
#                                      texto-traducido  \
# 0   Poor #MasistasIgnorantes think that because t...
# 1   Poor #MasistasIgnorantes think that because t...
# 2   Poor #MasistasIgnorantes think that because t...
# 3   @DraInterleucina @LuisFerCamachoV @Elgobernad...
# 4   The tongo was always evil. He ordered his fat...
#
#                                       texto-original  compound_nltk  \
# 0  Pobres #MasistasIgnorantes piensan que por and...        -0.0258
# 1  Pobres #MasistasIgnorantes piensan que por and...        -0.0258
# 2  Pobres #MasistasIgnorantes piensan que por and...        -0.0258
# 3  @DraInterleucina @LuisFerCamachoV @Elgobernado...         0.0000
# 4  El tongo siempre fue maleante. Mandó a desvali...        -0.8625
#
#    polarity_tb  subjectivity_tb
# 0     0.178788         0.651515
# 1     0.178788         0.651515
# 2     0.178788         0.651515
# 3     0.000000         0.000000
# 4    -0.583333         0.666667

# %%
# drop duplicates in texto-original
sentimientos = sentimientos.drop_duplicates(subset=['texto-original'])
# delete column texto-traducido
sentimientos = sentimientos.drop(columns=['texto-traducido'])

sentimientos.head()
# Out:
#                                       texto-original  compound_nltk  \
# 0  Pobres #MasistasIgnorantes piensan que por and...        -0.0258
# 3  @DraInterleucina @LuisFerCamachoV @Elgobernado...         0.0000
# 4  El tongo siempre fue maleante. Mandó a desvali...        -0.8625
# 5  Así justifica lo tan obvio 🙄como su supuesto a...         0.3612
# 7                         @grupoeldeber #revocatongo         0.0000
#
#    polarity_tb  subjectivity_tb
# 0     0.178788         0.651515
# 3     0.000000         0.000000
# 4    -0.583333         0.666667
# 5    -0.050000         0.300000
# 7     0.000000         0.000000

# %%
sentimientos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 89
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   texto-original   36 non-null     object
#  1   compound_nltk    36 non-null     float64
#  2   polarity_tb      36 non-null     float64
#  3   subjectivity_tb  36 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.4+ KB

# %%
# in sentimientos.describe() show just count, mean, std, min, max
sentimientos.describe().loc[['count', 'mean', 'min', 'max']]
# Out:
#        compound_nltk  polarity_tb  subjectivity_tb
# count      36.000000    36.000000         36.00000
# mean       -0.129739    -0.010959          0.24134
# min        -0.931300    -0.583333          0.00000
# max         0.806800     0.500000          1.00000

# %%
puntos3d = pd.read_excel('../data/2_processed/0_texto(sinrep)_puntos3d.xlsx')
puntos3d = puntos3d.drop(puntos3d.columns[0], axis=1)
puntos3d.head()
# Out:
#                                       texto-original         x         y  \
# 0  Pobres #MasistasIgnorantes piensan que por and... -0.919580 -0.824795
# 1  @DraInterleucina @LuisFerCamachoV @Elgobernado... -1.109628  1.176379
# 2  El tongo siempre fue maleante. Mandó a desvali...  6.045797 -0.501563
# 3  Así justifica lo tan obvio 🙄como su supuesto a...  3.762716  1.338456
# 4                         @grupoeldeber #revocatongo -2.330226  0.928894
#
#           z
# 0 -0.407660
# 1  0.033446
# 2  0.545565
# 3 -0.464437
# 4 -0.321120

# %%
puntos3d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   texto-original  36 non-null     object
#  1   x               36 non-null     float64
#  2   y               36 non-null     float64
#  3   z               36 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.6+ KB

# %%
# export to excel in ../data/2_processed
sentimientos.to_excel('../data/2_processed/1_sentimientos.xlsx', index=False)

# %%
df = pd.read_excel('../data/2_processed/1_sentimientos.xlsx')
df.head()
# Out:
#                                       texto-original  compound_nltk  \
# 0  Pobres #MasistasIgnorantes piensan que por and...        -0.0258
# 1  @DraInterleucina @LuisFerCamachoV @Elgobernado...         0.0000
# 2  El tongo siempre fue maleante. Mandó a desvali...        -0.8625
# 3  Así justifica lo tan obvio 🙄como su supuesto a...         0.3612
# 4                         @grupoeldeber #revocatongo         0.0000
#
#    polarity_tb  subjectivity_tb
# 0     0.178788         0.651515
# 1     0.000000         0.000000
# 2    -0.583333         0.666667
# 3    -0.050000         0.300000
# 4     0.000000         0.000000

# %% [markdown]
# ### Crear html con los resultados finales

# %%
html = f'''
    <!DOCTYPE html>
    <html lang="es">
        <head>
            <meta charset="UTF-8">
            <meta http-equiv="X-UA-Compatible" content="IE=edge">
            <meta name="viewport" content="width=device-width, initial-scale=1.0">

            <title>Resumen de los resultados obtenidos</title>

            <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css">
            <link rel="stylesheet" href="estilos/styles.css">
        </head>
        <body>
        <div class="section padding-bottom-big over-hide">
        <div class="container">
        <div class="row">
        <div class="col-12 text-center mt-3 mb-2">
        <div class="blog-post-text">
            <h2>Tablas obtenidas</h2>
            <p class="mb-3 mt-3">A continuación se describirá las tablas generadas</p>

            <h3>Tabla de tweets en espacio 3D</h3>
            <p class="mb-3 mt-3">Obtenida al aplicar el modelo BERT preentrenado para español a los tweets, y reducirlos a 3 dimensiones.</p>
            ''' + puntos3d.head(3).to_html().replace('<tr style="text-align: right;">', '<tr style="text-align: center;">') + '''

            <p class="mb-3 mt-3">Al hacer clustering se generó la grafica 3_elbow-method.png con el propósito de aplicar el método elbow</p>
            <img src='figures/3_elbow-method.png' width="700">

            <p class="mb-3 mt-3">La gráfica 3_count_elements_in_clusters.png muestra la cantidad de elementos en cada cluster al aplicar el algoritmo de clustering a nuestra tabla.</p>
            <img src='figures/3_count_elements_in_clusters.png' width="700">

            <p class="mb-3 mt-3">El archivo 3d-scatter-plot.html es una visualización interactiva de los puntos en el espacio tridimensional.</p>
            ''' + '''<img src='figures/3d-scatter-plot.png' width="700">''' + '''

            <h3>Tabla de análisis de sentimientos</h3>
            <p class="mb-3 mt-3">Obtenida al aplicar un análisis de sentimientos a los tweets.</p>
            ''' + sentimientos.head(3).to_html().replace('<tr style="text-align: right;">', '<tr style="text-align: center;">') + '''
            <p class="mb-3 mt-3">La siguiente tabla es una descripción de la tabla obtenida.</p>
            <div style="margin: auto; display: block; width: 50%;">''' + sentimientos.describe().loc[['count', 'mean', 'min', 'max']].to_html().replace('<tr style="text-align: right;">', '<tr style="text-align: center;">').replace('<table border="1" class="dataframe">', '<table border="1" class="dataframe" style="margin : auto;">') + '''</div>

            <p class="mb-3 mt-3">Al analizar el texto, se generó una nube de palabras wordcloud.png.</p>
            <img src='figures/wordcloud.png' width="700">
        </div>
        </div>
        </div>
        </div>
        </div>
        </body>
    </html>
    '''

with open('../reports/html_report.html', 'w', encoding="utf-8") as f:
    f.write(html)
